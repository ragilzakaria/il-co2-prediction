# %%
import pandas as pd
import os

# --- Helper function to count electrons ---
def get_electron_count_and_multiplicity(xyz_file_path, charge):
    atomic_numbers = {'H': 1, 'C': 6, 'N': 7, 'O': 8, 'F': 9, 'P': 15, 'S': 16, 'Cl': 17, 'Br': 35, 'B': 5}
    total_electrons = 0
    with open(xyz_file_path, 'r') as f:
        lines = f.readlines()[2:] # Skip header lines
        for line in lines:
            atom_symbol = line.split()[0]
            if atom_symbol in atomic_numbers:
                total_electrons += atomic_numbers[atom_symbol]
            else:
                raise ValueError(f"Unknown atom '{atom_symbol}' in {xyz_file_path}")

    # Adjust for the ion's charge
    final_electron_count = total_electrons - charge

    # Determine multiplicity
    if final_electron_count % 2 == 0:
        multiplicity = 1 # Even electrons -> Singlet
    else:
        multiplicity = 2 # Odd electrons -> Doublet

    return final_electron_count, multiplicity

# --- Main Script ---
ions_list_file = '../data/ions_with_smiles.csv'
structures_dir = '../structures/'
output_dir = '../calculations_individual/'
os.makedirs(output_dir, exist_ok=True)

orca_template = """! r2SCAN-3c Opt Freq MiniPrint
* xyzfile {charge} {multiplicity} {xyz_filename}
"""

try:
    df_ions = pd.read_csv(ions_list_file)
    print(f"Found {len(df_ions)} unique ions to process.")

    for index, row in df_ions.iterrows():
        ion_abbr = row['ion_abbreviation']
        ion_type = row['ion_type']
        charge = 1 if ion_type == 'cation' else -1

        safe_name = ion_abbr.strip('[]').replace('+', '_p').replace('-', '_m').replace('(', '_').replace(')', '_')
        xyz_filename_base = safe_name + '.xyz'
        xyz_filepath_relative = os.path.join(structures_dir, xyz_filename_base)

        if not os.path.exists(xyz_filepath_relative):
            continue

        # Get the correct multiplicity for this ion
        e_count, mult = get_electron_count_and_multiplicity(xyz_filepath_relative, charge)

        xyz_path_for_orca = f"../structures/{xyz_filename_base}"
        inp_content = orca_template.format(charge=charge, multiplicity=mult, xyz_filename=xyz_path_for_orca)

        output_path = os.path.join(output_dir, safe_name + '.inp')
        with open(output_path, 'w') as f_out:
            f_out.write(inp_content)

        print(f"Generated: {safe_name}.inp (Charge: {charge}, Electrons: {e_count}, Multiplicity: {mult})")

    print(f"\nProcess complete.")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Found 84 unique ions to process.
# Generated: _ETO_2IM.inp (Charge: 1, Electrons: 84, Multiplicity: 1)
# Generated: BBIM.inp (Charge: 1, Electrons: 100, Multiplicity: 1)
# Generated: BMIM.inp (Charge: 1, Electrons: 76, Multiplicity: 1)
# Generated: BMMIM.inp (Charge: 1, Electrons: 84, Multiplicity: 1)
# Generated: BMPYR.inp (Charge: 1, Electrons: 80, Multiplicity: 1)
# Generated: C12MIM.inp (Charge: 1, Electrons: 140, Multiplicity: 1)
# Generated: C3MPYR.inp (Charge: 1, Electrons: 72, Multiplicity: 1)
# Generated: C3OMIM.inp (Charge: 1, Electrons: 76, Multiplicity: 1)
# Generated: C4MPY.inp (Charge: 1, Electrons: 82, Multiplicity: 1)
# Generated: C4PY.inp (Charge: 1, Electrons: 74, Multiplicity: 1)
# Generated: C5MIM.inp (Charge: 1, Electrons: 84, Multiplicity: 1)
# Generated: C5MPYR.inp (Charge: 1, Electrons: 88, Multiplicity: 1)
# Generated: C5O2MIM.inp (Charge: 1, Electrons: 100, Multiplicity: 1)
# Generated: C6F9MIM.inp (Charge: 1, Electrons: 164, Multiplicity: 1)
# Generated: C7MIM.inp (Charge: 1, Electrons: 100, Multiplicity: 1)
# Generated: C7MPYR.inp (Charge: 1, Electrons: 104, Multiplicity: 1)
# Generated: C8F13MIM.inp (Charge: 1, Electrons: 212, Multiplicity: 1)
# Generated: C9MPYR.inp (Charge: 1, Electrons: 120, Multiplicity: 1)
# Generated: COCMPYR.inp (Charge: 1, Electrons: 72, Multiplicity: 1)
# Generated: DMIM.inp (Charge: 1, Electrons: 124, Multiplicity: 1)
# Generated: EMIM.inp (Charge: 1, Electrons: 60, Multiplicity: 1)
# Generated: HMIM.inp (Charge: 1, Electrons: 92, Multiplicity: 1)
# Generated: HMMIM.inp (Charge: 1, Electrons: 169, Multiplicity: 2)
# Generated: HMPYR.inp (Charge: 1, Electrons: 96, Multiplicity: 1)
# Generated: HMPY.inp (Charge: 1, Electrons: 98, Multiplicity: 1)
# Generated: HOC2MIM.inp (Charge: 1, Electrons: 68, Multiplicity: 1)
# Generated: HOC3MIM.inp (Charge: 1, Electrons: 76, Multiplicity: 1)
# Generated: HOEPY.inp (Charge: 1, Electrons: 66, Multiplicity: 1)
# Generated: MDEA.inp (Charge: 1, Electrons: 65, Multiplicity: 2)
# Generated: MMIM.inp (Charge: 1, Electrons: 52, Multiplicity: 1)
# Generated: N1,1,1,2_mOH.inp (Charge: 1, Electrons: 58, Multiplicity: 1)
# Generated: N1,1,3,2_mOH.inp (Charge: 1, Electrons: 74, Multiplicity: 1)
# Generated: N1,4,4,4.inp (Charge: 1, Electrons: 114, Multiplicity: 1)
# Generated: N1,8,8,8.inp (Charge: 1, Electrons: 210, Multiplicity: 1)
# Generated: N2,1,1,3.inp (Charge: 1, Electrons: 66, Multiplicity: 1)
# Generated: N4,1,1,1.inp (Charge: 1, Electrons: 66, Multiplicity: 1)
# Generated: N6,1,1,1.inp (Charge: 1, Electrons: 82, Multiplicity: 1)
# Generated: NMIM.inp (Charge: 1, Electrons: 116, Multiplicity: 1)
# Generated: OMIM.inp (Charge: 1, Electrons: 108, Multiplicity: 1)
# Generated: OMPYR.inp (Charge: 1, Electrons: 112, Multiplicity: 1)
# Generated: P1,4,4,4.inp (Charge: 1, Electrons: 122, Multiplicity: 1)
# Generated: P2,4,4,4.inp (Charge: 1, Electrons: 130, Multiplicity: 1)
# Generated: P4,4,4,4.inp (Charge: 1, Electrons: 181, Multiplicity: 2)
# Generated: P6,6,6,14.inp (Charge: 1, Electrons: 274, Multiplicity: 1)
# Generated: PMIM.inp (Charge: 1, Electrons: 68, Multiplicity: 1)
# Generated: PMPY.inp (Charge: 1, Electrons: 74, Multiplicity: 1)
# Generated: PMPip.inp (Charge: 1, Electrons: 80, Multiplicity: 1)
# Generated: S222.inp (Charge: 1, Electrons: 66, Multiplicity: 1)
# Generated: aMIM.inp (Charge: 1, Electrons: 66, Multiplicity: 1)
# Generated: deme.inp (Charge: 1, Electrons: 82, Multiplicity: 1)
# Generated: he.inp (Charge: 1, Electrons: 34, Multiplicity: 1)
# Generated: hea.inp (Charge: 1, Electrons: 58, Multiplicity: 1)
# Generated: m_m2_mHEA.inp (Charge: 1, Electrons: 42, Multiplicity: 1)
# Generated: oleyl_mMIM.inp (Charge: 1, Electrons: 186, Multiplicity: 1)
# Generated: thma.inp (Charge: 1, Electrons: 90, Multiplicity: 1)
# Generated: N4,4,4,4.inp (Charge: 1, Electrons: 138, Multiplicity: 1)
# Generated: Tf2N.inp (Charge: -1, Electrons: 138, Multiplicity: 1)
# Generated: MeSO3.inp (Charge: -1, Electrons: 50, Multiplicity: 1)
# Generated: BETA.inp (Charge: -1, Electrons: 186, Multiplicity: 1)
# Generated: BF4.inp (Charge: -1, Electrons: 42, Multiplicity: 1)
# Generated: C_CN_3.inp (Charge: -1, Electrons: 46, Multiplicity: 1)
# Generated: C3F7CO2.inp (Charge: -1, Electrons: 104, Multiplicity: 1)
# Generated: Cl.inp (Charge: -1, Electrons: 18, Multiplicity: 1)
# Generated: DBPO4.inp (Charge: -1, Electrons: 115, Multiplicity: 2)
# Generated: DCA.inp (Charge: -1, Electrons: 35, Multiplicity: 2)
# Generated: MDEGSO4.inp (Charge: -1, Electrons: 106, Multiplicity: 1)
# Generated: MeSO4.inp (Charge: -1, Electrons: 58, Multiplicity: 1)
# Generated: NO3.inp (Charge: -1, Electrons: 32, Multiplicity: 1)
# Generated: NfO.inp (Charge: -1, Electrons: 146, Multiplicity: 1)
# Generated: PF6.inp (Charge: -1, Electrons: 70, Multiplicity: 1)
# Generated: SCN.inp (Charge: -1, Electrons: 30, Multiplicity: 1)
# Generated: TDfO.inp (Charge: -1, Electrons: 194, Multiplicity: 1)
# Generated: TFA.inp (Charge: -1, Electrons: 56, Multiplicity: 1)
# Generated: TfO.inp (Charge: -1, Electrons: 74, Multiplicity: 1)
# Generated: methide.inp (Charge: -1, Electrons: 202, Multiplicity: 1)
# Generated: FSA.inp (Charge: -1, Electrons: 90, Multiplicity: 1)
# Generated: DEPO4.inp (Charge: -1, Electrons: 82, Multiplicity: 1)
# Generated: EtSO4.inp (Charge: -1, Electrons: 66, Multiplicity: 1)
# Generated: HSO4.inp (Charge: -1, Electrons: 50, Multiplicity: 1)
# Generated: TCB.inp (Charge: -1, Electrons: 58, Multiplicity: 1)
# Generated: DMPO4.inp (Charge: -1, Electrons: 66, Multiplicity: 1)
# Generated: TOS.inp (Charge: -1, Electrons: 90, Multiplicity: 1)
# Generated: FOR.inp (Charge: -1, Electrons: 24, Multiplicity: 1)
# Generated: C12PhSO3.inp (Charge: -1, Electrons: 179, Multiplicity: 2)
#
# Process complete.
