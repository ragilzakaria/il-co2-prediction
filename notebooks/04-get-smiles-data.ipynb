# %%
import pandas as pd
import requests
import time

# Input file with full ion names
input_file = '../data/unique_ions_with_names.csv'
# Output file for the results
output_file = '../data/ions_with_smiles.csv'

try:
    df_ions = pd.read_csv(input_file)
    # Drop any rows where the ion_name might be missing, just in case
    df_ions.dropna(subset=['ion_name'], inplace=True)
    print(f"Loaded {len(df_ions)} unique ion names from '{input_file}'")

    # Create a new column to store the SMILES strings
    df_ions['smiles'] = ''

    # --- Loop through each ion and fetch its SMILES from PubChem ---
    for index, row in df_ions.iterrows():
        ion_name = row['ion_name']

        # Construct the URL for the PubChem API
        url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/{ion_name}/property/CanonicalSMILES/TXT"

        try:
            # Make the web request
            response = requests.get(url, timeout=10) # Added a timeout

            if response.status_code == 200:
                # If successful, the SMILES is the text content of the response
                smiles = response.text.strip()
                df_ions.at[index, 'smiles'] = smiles
                print(f"SUCCESS: Found SMILES for '{ion_name}'")
            else:
                # If the ion is not found, the status code will be 404
                print(f"WARNING: Could not find '{ion_name}' in PubChem (Status: {response.status_code})")
                df_ions.at[index, 'smiles'] = 'NOT_FOUND'

        except requests.exceptions.RequestException as e:
            print(f"ERROR: A network error occurred for '{ion_name}': {e}")
            df_ions.at[index, 'smiles'] = 'REQUEST_ERROR'

        # Be polite to the server and wait a moment between requests
        time.sleep(0.3)

        # Save the final DataFrame with the new smiles column
    df_ions.to_csv(output_file, index=False)

    print(f"\nProcess complete. Results saved to '{output_file}'")
    print("\n--- Preview of the Results ---")
    print(df_ions.head())

except FileNotFoundError:
    print(f"ERROR: Could not find the input file at '{input_file}'")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Loaded 84 unique ion names from '../data/unique_ions_with_names.csv'
# ERROR: A network error occurred for '1,3-diethoxyimidazolium': HTTPSConnectionPool(host='pubchem.ncbi.nlm.nih.gov', port=443): Read timed out. (read timeout=10)
# SUCCESS: Found SMILES for '1,3-dibutylimidazolium'
# SUCCESS: Found SMILES for '1-butyl-3-methyl-imidazolium'
# SUCCESS: Found SMILES for '1-butyl-2,3-dimethylimidazolium'
# WARNING: Could not find '1-butyl-1-methyl-pyrrolidinium' in PubChem (Status: 404)
# SUCCESS: Found SMILES for '1-dodecyl-3-methylimidazolium'
# WARNING: Could not find '1-propyl-1-methylpyrrolidinium' in PubChem (Status: 404)
# WARNING: Could not find '1-(2-methoxyethyl)-3-methylimidazolium' in PubChem (Status: 404)
# SUCCESS: Found SMILES for '1-butyl-3-methylpyridinium'
# SUCCESS: Found SMILES for '1-butylpyridinium'
# WARNING: Could not find '1-pentyl-3-methyl-imidazolium' in PubChem (Status: 404)
# WARNING: Could not find '1-pentyl-1-methylpyrrolidinium' in PubChem (Status: 404)
# WARNING: Could not find '1-[2-(2-methoxyethoxy)ethyl]-3-methylimidazolium' in PubChem (Status: 404)
# WARNING: Could not find '1-(3,3,4,4,5,5,6,6,6-nonafluorohexyl)-3-methyl-imidazolium' in PubChem (Status: 404)
# WARNING: Could not find '1-heptyl-3-methylimidazolium' in PubChem (Status: 404)
# WARNING: Could not find '1-heptyl-1-methylpyrrolidinium' in PubChem (Status: 404)
# WARNING: Could not find '1-(3,3,4,4,5,5,6,6,7,7,8,8,8-tridecafluorooctyl)-3-methyl-imidazolium' in PubChem (Status: 404)
# WARNING: Could not find '1-nonyl-1-methylpyrrolidinium' in PubChem (Status: 404)
# WARNING: Could not find '1-methoxymethyl-1-methylpyrrolidinium' in PubChem (Status: 404)
0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# SUCCESS: Found SMILES for 'methanesulfonate'
# WARNING: Could not find 'bis(pentafluoroethanesulfonyl)amide' in PubChem (Status: 404)
# SUCCESS: Found SMILES for 'tetrafluoroborate'
# SUCCESS: Found SMILES for 'tricyanomethanide'
# WARNING: Could not find 'heptafluorobutyrate' in PubChem (Status: 404)
# SUCCESS: Found SMILES for 'chloride'
# SUCCESS: Found SMILES for 'dibutylphosphate'
# SUCCESS: Found SMILES for 'dicyanamide'
# WARNING: Could not find '2-(2-methoxyethoxy)ethylsulfate' in PubChem (Status: 404)
# SUCCESS: Found SMILES for 'methylsulfate'
# SUCCESS: Found SMILES for 'nitrate'
# WARNING: Could not find 'nonafluorobutylsulfonate' in PubChem (Status: 404)
# ERROR: A network error occurred for 'hexafluorophosphate': HTTPSConnectionPool(host='pubchem.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /rest/pug/compound/name/hexafluorophosphate/property/CanonicalSMILES/TXT (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x10ce79710>: Failed to establish a new connection: [Errno 61] Connection refused'))
# ERROR: A network error occurred for 'thiocyanate': HTTPSConnectionPool(host='pubchem.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /rest/pug/compound/name/thiocyanate/property/CanonicalSMILES/TXT (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x10ce5bfd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# WARNING: Could not find 'tridecafluorohexylsulfonate' in PubChem (Status: 404)
# SUCCESS: Found SMILES for 'trifluoroacetate'
# WARNING: Could not find 'trifuoromethanesulfonate' in PubChem (Status: 404)
# WARNING: Could not find 'tris(trifluoromethylsulfonyl)methide' in PubChem (Status: 404)
# WARNING: Could not find 'bis(fluorosulfonyl)amide' in PubChem (Status: 404)
# ERROR: A network error occurred for 'diethylphosphate': HTTPSConnectionPool(host='pubchem.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /rest/pug/compound/name/diethylphosphate/property/CanonicalSMILES/TXT (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x10ce78090>: Failed to establish a new connection: [Errno 61] Connection refused'))
# ERROR: A network error occurred for 'ethylsulfate': HTTPSConnectionPool(host='pubchem.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /rest/pug/compound/name/ethylsulfate/property/CanonicalSMILES/TXT (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x10ce824d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# ERROR: A network error occurred for 'hydrogen sulfate': HTTPSConnectionPool(host='pubchem.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /rest/pug/compound/name/hydrogen%20sulfate/property/CanonicalSMILES/TXT (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x10ce83f50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# WARNING: Could not find 'tetracyanoborate' in PubChem (Status: 404)
# ERROR: A network error occurred for 'dimethylphosphate': HTTPSConnectionPool(host='pubchem.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /rest/pug/compound/name/dimethylphosphate/property/CanonicalSMILES/TXT (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x10ce81250>: Failed to establish a new connection: [Errno 61] Connection refused'))
# SUCCESS: Found SMILES for 'p-toluenesulfonate'
# SUCCESS: Found SMILES for 'formate'
# ERROR: A network error occurred for 'dodecylbenzenesulfonate': HTTPSConnectionPool(host='pubchem.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /rest/pug/compound/name/dodecylbenzenesulfonate/property/CanonicalSMILES/TXT (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x10ce80b90>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# Process complete. Results saved to '../data/ions_with_smiles.csv'
#
# --- Preview of the Results ---
#   ion_abbreviation                         ion_name ion_type  \
# 0       [(ETO)2IM]          1,3-diethoxyimidazolium   cation
# 1           [BBIM]           1,3-dibutylimidazolium   cation
# 2           [BMIM]     1-butyl-3-methyl-imidazolium   cation
# 3          [BMMIM]  1-butyl-2,3-dimethylimidazolium   cation
# 4          [BMPYR]   1-butyl-1-methyl-pyrrolidinium   cation
#
#                    smiles
# 0           REQUEST_ERROR
# 1  CCCCN1C=C[N+](=C1)CCCC
# 2     CCCCN1C=C[N+](=C1)C
# 3    CCCCN1C=C[N+](=C1C)C
# 4               NOT_FOUND
